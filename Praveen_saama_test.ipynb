# %%
import requests
import json
import warnings
warnings.filterwarnings('ignore')
import pandas as pd

# %%
get1=requests.get('https://pharmanlp-177020.uc.r.appspot.com/api/1/StudyHack/ae/subject/list', verify=False)
get2=requests.get('https://pharmanlp-177020.uc.r.appspot.com/api/1/StudyHack/cm/subject/list', verify=False)

# %%
out1=json.loads(get1.text)
out2=json.loads(get2.text)

# %%
Subject_ID_ae=pd.DataFrame(out1)
print(Subject_ID_ae.head())
Subject_ID_cm=pd.DataFrame(out2)
print(Subject_ID_cm.head())
# Out:
#     status    data                            request_id
# 0  success   76809  337e15c7-2618-40f5-9b03-a21c423bda23
# 1  success  105792  337e15c7-2618-40f5-9b03-a21c423bda23
# 2  success  117691  337e15c7-2618-40f5-9b03-a21c423bda23
# 3  success  120205  337e15c7-2618-40f5-9b03-a21c423bda23
# 4  success  130301  337e15c7-2618-40f5-9b03-a21c423bda23
#     status    data                            request_id
# 0  success   76809  f9a1592c-6a94-4bad-bded-91460425a300
# 1  success  130301  f9a1592c-6a94-4bad-bded-91460425a300
# 2  success  132645  f9a1592c-6a94-4bad-bded-91460425a300
# 3  success  138700  f9a1592c-6a94-4bad-bded-91460425a300
# 4  success  166621  f9a1592c-6a94-4bad-bded-91460425a300

# %%
get3=requests.get('https://pharmanlp-177020.uc.r.appspot.com/api/1/StudyHack/ae/subject/105792/list', verify=False)
get4=requests.get('https://pharmanlp-177020.uc.r.appspot.com/api/1/StudyHack/cm/subject/105792/list',verify=False)

# %%
out3=json.loads(get3.text)
out4=json.loads(get4.text)

# %%
appended_data= []
for i in Subject_ID_ae['data']:
    get3=requests.get(f'https://pharmanlp-177020.uc.r.appspot.com/api/1/StudyHack/ae/subject/{i}/list', verify=False)
    out3=json.loads(get3.text)
    Task1_ae=pd.DataFrame(out3)
    for j in Task1_ae['data']:
        appended_data.append(j)

# %%
Test1_ae=pd.DataFrame(appended_data)
Test1_ae
# Out:
#          studyid  siteid    subjid  subjectid  visitindex visitnam formname  \
# 0      StudyHack    5173  51735001      76809           1     AECM    AE202
# 1      StudyHack    5173  51735001      76809           1     AECM    AE202
# 2      StudyHack    5173  51735001      76809           1     AECM    AE202
# 3      StudyHack    5173  51735001      76809           1     AECM    AE202
# 4      StudyHack    5173  51735001      76809           1     AECM    AE202
# ...          ...     ...       ...        ...         ...      ...      ...
# 20055  StudyHack    5018  50185008   18291148           1     AECM    AE202
# 20056  StudyHack    5018  50185008   18291148           1     AECM    AE202
# 20057  StudyHack    5018  50185008   18291148           1     AECM    AE202
# 20058  StudyHack    5018  50185008   18291148           1     AECM    AE202
# 20059  StudyHack    5018  50185008   18291148           1     AECM    AE202
#
# ...

# %%
appended_data1 = []
for i in Subject_ID_cm['data']:
    get4=requests.get(f'https://pharmanlp-177020.uc.r.appspot.com/api/1/StudyHack/cm/subject/{i}/list', verify=False)
    out4=json.loads(d.text)
    Task1_cm=pd.DataFrame(out4)
    for j in Task1_cm['data']:
        appended_data1.append(j)

# %%
Testdata_cm=pd.DataFrame(appended_data1)
Testdata_cm
# Out:
#          studyid  siteid    subjid  subjectid  visitid  visitidx visitnam  \
# 0      StudyHack    5173  51735001      76809    38942         1     AECM
# 1      StudyHack    5173  51735001      76809    38942         1     AECM
# 2      StudyHack    5173  51735001      76809    38942         1     AECM
# 3      StudyHack    5173  51735001      76809    38942         1     AECM
# 4      StudyHack    5173  51735001      76809    38942         1     AECM
# ...          ...     ...       ...        ...      ...       ...      ...
# 42440  StudyHack    5184  51845002   55397989    38942         1     AECM
# 42441  StudyHack    5184  51845002   55397989    38942         1     AECM
# 42442  StudyHack    5184  51845002   55397989    38942         1     AECM
# 42443  StudyHack    5184  51845002   55397989    38942         1     AECM
# 42444  StudyHack    5184  51845002   55397989    38942         1     AECM
#
#       formname  formid  formidx  ...  cmstdat_dts    cmendat cmendat_dtr  \
# ...

# %%
Task1=pd.merge(Testdata_ae,Testdata_cm,on=['studyid','siteid','subjid','subjectid'])

# %%
Task1
# Out:
#            studyid  siteid    subjid  subjectid  visitindex visitnam_x  \
# 0        StudyHack    5173  51735001      76809           1       AECM
# 1        StudyHack    5173  51735001      76809           1       AECM
# 2        StudyHack    5173  51735001      76809           1       AECM
# 3        StudyHack    5173  51735001      76809           1       AECM
# 4        StudyHack    5173  51735001      76809           1       AECM
# ...            ...     ...       ...        ...         ...        ...
# 1175249  StudyHack    5018  50185007   18282353           1       AECM
# 1175250  StudyHack    5018  50185007   18282353           1       AECM
# 1175251  StudyHack    5018  50185007   18282353           1       AECM
# 1175252  StudyHack    5018  50185007   18282353           1       AECM
# 1175253  StudyHack    5018  50185007   18282353           1       AECM
#
#         formname_x  formid_x  formidx_x   formindex_x  ... cmstdat_dts  \
# ...
